# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %%
properties
# Out:
#     Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0          NaT      E09000001          E09000002  E09000003  E09000004
# 1   1995-01-01          91449            50460.2    93284.5    64958.1
# 2   1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3   1995-03-01        79120.7              51269    92247.5    64367.5
# 4   1995-04-01        77101.2            53133.5    90762.9    64277.7
# ..         ...            ...                ...        ...        ...
# 311 2020-11-01         770972             305053     530931     347116
# 312 2020-12-01         794277             310281     533160     353710
# 313 2021-01-01         762757             314068     541622     358243
# 314 2021-02-01         744324             319589     536096     361861
# 315 2021-03-01         864354             317185     534005     367015
#
#          Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# ...

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
print(type(properties))
print(properties.columns)
print(properties[['Unnamed: 0','City of London']])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')
#     Unnamed: 0 City of London
# 0          NaT      E09000001
# 1   1995-01-01          91449
# 2   1995-02-01        82202.8
# ...

# %%
prop_columns_0and1 = properties[['Unnamed: 0','City of London']]

# %%
prop_columns_0and1
# Out:
#     Unnamed: 0 City of London
# 0          NaT      E09000001
# 1   1995-01-01          91449
# 2   1995-02-01        82202.8
# 3   1995-03-01        79120.7
# 4   1995-04-01        77101.2
# ..         ...            ...
# 311 2020-11-01         770972
# 312 2020-12-01         794277
# 313 2021-01-01         762757
# 314 2021-02-01         744324
# 315 2021-03-01         864354
#
# [316 rows x 2 columns]

# %%
properties.iloc[:, 0 : 4]
# Out:
#     Unnamed: 0 City of London Barking & Dagenham     Barnet
# 0          NaT      E09000001          E09000002  E09000003
# 1   1995-01-01          91449            50460.2    93284.5
# 2   1995-02-01        82202.8            51085.8    93190.2
# 3   1995-03-01        79120.7              51269    92247.5
# 4   1995-04-01        77101.2            53133.5    90762.9
# ..         ...            ...                ...        ...
# 311 2020-11-01         770972             305053     530931
# 312 2020-12-01         794277             310281     533160
# 313 2021-01-01         762757             314068     541622
# 314 2021-02-01         744324             319589     536096
# 315 2021-03-01         864354             317185     534005
#
# [316 rows x 4 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
"""
Follow the goals of -
1. Each variable has a column.
2. Each observation forms a row of values.
"""
properties_T = properties.T

# %%
properties_T
# Out:
#                             0                    1                    2    \
# Unnamed: 0                  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London        E09000001                91449              82202.8
# Barking & Dagenham    E09000002              50460.2              51085.8
# Barnet                E09000003              93284.5              93190.2
# Bexley                E09000004              64958.1              64787.9
# Brent                 E09000005              71306.6              72022.3
# Bromley               E09000006              81671.5              81657.6
# Camden                E09000007               120933               119509
# Croydon               E09000008              69158.2              68951.1
# Ealing                E09000009              79885.9              80897.1
# Enfield               E09000010              72514.7              73155.2
# Greenwich             E09000011              62300.1              60993.3
# ...

# %%
# Transpose your dataframe, check out what its row indexes are, and reset the index. 
# You  also might find you need to assign the values of the first row to your column headings 
properties_T = properties_T.reset_index()

# %%
properties_T
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001                91449              82202.8
# 2     Barking & Dagenham  E09000002              50460.2              51085.8
# 3                 Barnet  E09000003              93284.5              93190.2
# 4                 Bexley  E09000004              64958.1              64787.9
# 5                  Brent  E09000005              71306.6              72022.3
# 6                Bromley  E09000006              81671.5              81657.6
# 7                 Camden  E09000007               120933               119509
# 8                Croydon  E09000008              69158.2              68951.1
# 9                 Ealing  E09000009              79885.9              80897.1
# 10               Enfield  E09000010              72514.7              73155.2
# ...

# %%
print(properties_T.head())
print(properties_T.iloc[0, :12])
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# ...

# %%
properties_T.iloc[[0,1,2]]
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
#
#                    306                  307                  308  \
# ...

# %%
print(properties_T.columns)
print(properties_T.iloc[[0]])
properties_T.iloc[0]
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            306,     307,     308,     309,     310,     311,     312,     313,
#            314,     315],
#       dtype='object', length=317)
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    306                  307                  308  \
# 0  2020-06-01 00:00:00  2020-07-01 00:00:00  2020-08-01 00:00:00
#
#                    309                  310                  311  \
# 0  2020-09-01 00:00:00  2020-10-01 00:00:00  2020-11-01 00:00:00
#
# ...

# %%
properties_T.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    306                  307                  308  \
# 0  2020-06-01 00:00:00  2020-07-01 00:00:00  2020-08-01 00:00:00
#
#                    309                  310                  311  \
# 0  2020-09-01 00:00:00  2020-10-01 00:00:00  2020-11-01 00:00:00
#
#                    312                  313                  314  \
# 0  2020-12-01 00:00:00  2021-01-01 00:00:00  2021-02-01 00:00:00
#
#                    315
# 0  2021-03-01 00:00:00
#
# [1 rows x 317 columns]

# %%
properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            306,     307,     308,     309,     310,     311,     312,     313,
#            314,     315],
#       dtype='object', length=317)

# %%
properties_T.columns = properties_T.iloc[0]

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
# Drop row 0, and re-assign
properties_T = properties_T.drop(0)

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# .rename() the columns 'Unname: 0' and 'NaN'
# Re-assign to properties_T
properties_T = properties_T.rename(columns = {'Unnamed: 0': 'Borough_Name', pd.NaT: 'Borough_ID'})

# %%
properties_T.head()
# Out:
# 0        Borough_Name Borough_ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
"""
Transform DF from wide format to tall by unpivoting values for datetime.month and Avg_price of a house
id_vars for [Borough_Name, Borough_ID] are established datetime variable, and
 

 df_tall = df_wide.melt(id_vars=['financial','company'])
"""

tall_properties = pd.melt(properties_T, id_vars= ['Borough_Name', 'Borough_ID'])

# %%
tall_properties
# Out:
#              Borough_Name Borough_ID          0    value
# 0          City of London  E09000001 1995-01-01    91449
# 1      Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2                  Barnet  E09000003 1995-01-01  93284.5
# 3                  Bexley  E09000004 1995-01-01  64958.1
# 4                   Brent  E09000005 1995-01-01  71306.6
# ...                   ...        ...        ...      ...
# 15115              LONDON  E12000007 2021-03-01   500310
# 15116          SOUTH EAST  E12000008 2021-03-01   348615
# 15117          SOUTH WEST  E12000009 2021-03-01   287650
# 15118         Unnamed: 47        NaN 2021-03-01      NaN
# 15119             England  E92000001 2021-03-01   274615
#
# [15120 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
tall_properties.dtypes
# Out:
# Borough_Name            object
# Borough_ID              object
# 0               datetime64[ns]
# value                   object
# dtype: object

# %%
tall_properties['value'] = pd.to_numeric(tall_properties['value'])

# %%
tall_properties.dtypes
# Out:
# Borough_Name            object
# Borough_ID              object
# 0               datetime64[ns]
# value                  float64
# dtype: object

# %%
tall_properties = tall_properties.rename(columns = {0: 'Month', 'value': 'Avg_price'})

# %%
tall_properties
# Out:
#              Borough_Name Borough_ID      Month     Avg_price
# 0          City of London  E09000001 1995-01-01   91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# ...                   ...        ...        ...           ...
# 15115              LONDON  E12000007 2021-03-01  500310.13620
# 15116          SOUTH EAST  E12000008 2021-03-01  348615.20040
# 15117          SOUTH WEST  E12000009 2021-03-01  287649.72450
# 15118         Unnamed: 47        NaN 2021-03-01           NaN
# 15119             England  E92000001 2021-03-01  274615.36520
#
# [15120 rows x 4 columns]

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
tall_properties['Borough_Name'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
len(tall_properties['Borough_Name'].unique())
# Out:
# 48

# %%
"""
26 non-boroughs are observed. Drop from DF.
Rows to be dropped include:
'Unnamed: 34'
'Unnamed: 37'
'NORTH EAST'
'NORTH WEST'
'YORKS & THE HUMBER'
'EAST MIDLANDS'
'WEST MIDLANDS'
'EAST OF ENGLAND'
'LONDON'
'SOUTH EAST'
'SOUTH WEST'
'Unnamed: 47'
'England'

"""

tall_properties[tall_properties['Borough_Name'] == 'Unnamed: 34']
# Out:
#       Borough_Name Borough_ID      Month  Avg_price
# 33     Unnamed: 34        NaN 1995-01-01        NaN
# 81     Unnamed: 34        NaN 1995-02-01        NaN
# 129    Unnamed: 34        NaN 1995-03-01        NaN
# 177    Unnamed: 34        NaN 1995-04-01        NaN
# 225    Unnamed: 34        NaN 1995-05-01        NaN
# ...            ...        ...        ...        ...
# 14913  Unnamed: 34        NaN 2020-11-01        NaN
# 14961  Unnamed: 34        NaN 2020-12-01        NaN
# 15009  Unnamed: 34        NaN 2021-01-01        NaN
# 15057  Unnamed: 34        NaN 2021-02-01        NaN
# 15105  Unnamed: 34        NaN 2021-03-01        NaN
#
# [315 rows x 4 columns]

# %%
tall_properties[tall_properties['Borough_Name'] == 'NORTH EAST']
# Out:
#       Borough_Name Borough_ID      Month     Avg_price
# 37      NORTH EAST  E12000001 1995-01-01   42076.35411
# 85      NORTH EAST  E12000001 1995-02-01   42571.98949
# 133     NORTH EAST  E12000001 1995-03-01   42369.72984
# 181     NORTH EAST  E12000001 1995-04-01   42095.84360
# 229     NORTH EAST  E12000001 1995-05-01   43266.45165
# ...            ...        ...        ...           ...
# 14917   NORTH EAST  E12000001 2020-11-01  138308.21530
# 14965   NORTH EAST  E12000001 2020-12-01  139671.03120
# 15013   NORTH EAST  E12000001 2021-01-01  140635.68870
# 15061   NORTH EAST  E12000001 2021-02-01  141634.34120
# 15109   NORTH EAST  E12000001 2021-03-01  145892.90010
#
# [315 rows x 4 columns]

# %%
tall_properties[tall_properties['Borough_Name'] == 'England']
# Out:
#       Borough_Name Borough_ID      Month     Avg_price
# 47         England  E92000001 1995-01-01   53202.77128
# 95         England  E92000001 1995-02-01   53096.15490
# 143        England  E92000001 1995-03-01   53201.28430
# 191        England  E92000001 1995-04-01   53590.85480
# 239        England  E92000001 1995-05-01   53678.24041
# ...            ...        ...        ...           ...
# 14927      England  E92000001 2020-11-01  264077.08140
# 14975      England  E92000001 2020-12-01  267363.35260
# 15023      England  E92000001 2021-01-01  267675.21460
# 15071      England  E92000001 2021-02-01  269976.04670
# 15119      England  E92000001 2021-03-01  274615.36520
#
# [315 rows x 4 columns]

# %%
tall_properties[tall_properties['Borough_Name'] == 'Unnamed: 47']
# Out:
#       Borough_Name Borough_ID      Month  Avg_price
# 46     Unnamed: 47        NaN 1995-01-01        NaN
# 94     Unnamed: 47        NaN 1995-02-01        NaN
# 142    Unnamed: 47        NaN 1995-03-01        NaN
# 190    Unnamed: 47        NaN 1995-04-01        NaN
# 238    Unnamed: 47        NaN 1995-05-01        NaN
# ...            ...        ...        ...        ...
# 14926  Unnamed: 47        NaN 2020-11-01        NaN
# 14974  Unnamed: 47        NaN 2020-12-01        NaN
# 15022  Unnamed: 47        NaN 2021-01-01        NaN
# 15070  Unnamed: 47        NaN 2021-02-01        NaN
# 15118  Unnamed: 47        NaN 2021-03-01        NaN
#
# [315 rows x 4 columns]

# %%
tall_properties[tall_properties['Avg_price'].isna()]
# Out:
#       Borough_Name Borough_ID      Month  Avg_price
# 33     Unnamed: 34        NaN 1995-01-01        NaN
# 36     Unnamed: 37        NaN 1995-01-01        NaN
# 46     Unnamed: 47        NaN 1995-01-01        NaN
# 81     Unnamed: 34        NaN 1995-02-01        NaN
# 84     Unnamed: 37        NaN 1995-02-01        NaN
# ...            ...        ...        ...        ...
# 15060  Unnamed: 37        NaN 2021-02-01        NaN
# 15070  Unnamed: 47        NaN 2021-02-01        NaN
# 15105  Unnamed: 34        NaN 2021-03-01        NaN
# 15108  Unnamed: 37        NaN 2021-03-01        NaN
# 15118  Unnamed: 47        NaN 2021-03-01        NaN
#
# [945 rows x 4 columns]

# %%
tall_properties.count()
# Out:
# Borough_Name    15120
# Borough_ID      14175
# Month           15120
# Avg_price       14175
# dtype: int64

# %%
# Remove all rows without an Avg_price i.e. NaN
clean_properties = tall_properties.dropna()
clean_properties
# Out:
#              Borough_Name Borough_ID      Month     Avg_price
# 0          City of London  E09000001 1995-01-01   91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# ...                   ...        ...        ...           ...
# 15114     EAST OF ENGLAND  E12000006 2021-03-01  315059.18820
# 15115              LONDON  E12000007 2021-03-01  500310.13620
# 15116          SOUTH EAST  E12000008 2021-03-01  348615.20040
# 15117          SOUTH WEST  E12000009 2021-03-01  287649.72450
# 15119             England  E92000001 2021-03-01  274615.36520
#
# [14175 rows x 4 columns]

# %%
clean_properties.count()
# Out:
# Borough_Name    14175
# Borough_ID      14175
# Month           14175
# Avg_price       14175
# dtype: int64

# %%
# Remove all non-boroughs, where:
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']
len(nonBoroughs)
# Out:
# 12

# %%
clean_properties[clean_properties['Borough_Name'].isin(nonBoroughs)]
# Out:
#              Borough_Name Borough_ID      Month     Avg_price
# 34           Inner London  E13000001 1995-01-01   78251.97650
# 35           Outer London  E13000002 1995-01-01   72958.79836
# 37             NORTH EAST  E12000001 1995-01-01   42076.35411
# 38             NORTH WEST  E12000002 1995-01-01   43958.48001
# 39     YORKS & THE HUMBER  E12000003 1995-01-01   44803.42878
# ...                   ...        ...        ...           ...
# 15114     EAST OF ENGLAND  E12000006 2021-03-01  315059.18820
# 15115              LONDON  E12000007 2021-03-01  500310.13620
# 15116          SOUTH EAST  E12000008 2021-03-01  348615.20040
# 15117          SOUTH WEST  E12000009 2021-03-01  287649.72450
# 15119             England  E92000001 2021-03-01  274615.36520
#
# [3780 rows x 4 columns]

# %%
# Remove using negation operator ~
clean_properties[~clean_properties['Borough_Name'].isin(nonBoroughs)]
# Out:
#              Borough_Name Borough_ID      Month     Avg_price
# 0          City of London  E09000001 1995-01-01   91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# ...                   ...        ...        ...           ...
# 15100              Sutton  E09000029 2021-03-01  395397.08970
# 15101       Tower Hamlets  E09000030 2021-03-01  496246.71500
# 15102      Waltham Forest  E09000031 2021-03-01  490895.15880
# 15103          Wandsworth  E09000032 2021-03-01  598279.43470
# 15104         Westminster  E09000033 2021-03-01  927993.33540
#
# [10395 rows x 4 columns]

# %%
df = clean_properties[~clean_properties['Borough_Name'].isin(nonBoroughs)]

# %%
df
# Out:
#              Borough_Name Borough_ID      Month     Avg_price
# 0          City of London  E09000001 1995-01-01   91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# ...                   ...        ...        ...           ...
# 15100              Sutton  E09000029 2021-03-01  395397.08970
# 15101       Tower Hamlets  E09000030 2021-03-01  496246.71500
# 15102      Waltham Forest  E09000031 2021-03-01  490895.15880
# 15103          Wandsworth  E09000032 2021-03-01  598279.43470
# 15104         Westminster  E09000033 2021-03-01  927993.33540
#
# [10395 rows x 4 columns]

# %%
df.dtypes
# Out:
# Borough_Name            object
# Borough_ID              object
# Month           datetime64[ns]
# Avg_price              float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
brent_prices = df[df['Borough_Name'] == 'Brent']

# %%
brent_prices
# Out:
#       Borough_Name Borough_ID      Month     Avg_price
# 4            Brent  E09000005 1995-01-01   71306.56698
# 52           Brent  E09000005 1995-02-01   72022.26197
# 100          Brent  E09000005 1995-03-01   72015.76274
# 148          Brent  E09000005 1995-04-01   72965.63094
# 196          Brent  E09000005 1995-05-01   73704.04743
# ...            ...        ...        ...           ...
# 14884        Brent  E09000005 2020-11-01  512271.05320
# 14932        Brent  E09000005 2020-12-01  495230.52000
# 14980        Brent  E09000005 2021-01-01  508184.28740
# 15028        Brent  E09000005 2021-02-01  513426.44500
# 15076        Brent  E09000005 2021-03-01  510532.79410
#
# [315 rows x 4 columns]

# %%
bx = brent_prices.plot(x = 'Month', y = 'Avg_price', kind = 'line')
bx.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
london_prices = df[df['Borough_Name'] == 'City of London']
london_prices
# Out:
#          Borough_Name Borough_ID      Month     Avg_price
# 0      City of London  E09000001 1995-01-01   91448.98487
# 48     City of London  E09000001 1995-02-01   82202.77314
# 96     City of London  E09000001 1995-03-01   79120.70256
# 144    City of London  E09000001 1995-04-01   77101.20804
# 192    City of London  E09000001 1995-05-01   84409.14932
# ...               ...        ...        ...           ...
# 14880  City of London  E09000001 2020-11-01  770971.95950
# 14928  City of London  E09000001 2020-12-01  794277.05010
# 14976  City of London  E09000001 2021-01-01  762756.60490
# 15024  City of London  E09000001 2021-02-01  744323.58820
# 15072  City of London  E09000001 2021-03-01  864353.53380
#
# [315 rows x 4 columns]

# %%
lx = london_prices.plot(x = 'Month', y = 'Avg_price', kind = 'line')
lx.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df['Year'] = df['Month'].apply(lambda t: t.year)
# Out:
# <ipython-input-103-056d0922c67e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Month'].apply(lambda t: t.year)

# %%
df
# Out:
#              Borough_Name Borough_ID      Month     Avg_price  Year
# 0          City of London  E09000001 1995-01-01   91448.98487  1995
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660  1995
# 2                  Barnet  E09000003 1995-01-01   93284.51832  1995
# 3                  Bexley  E09000004 1995-01-01   64958.09036  1995
# 4                   Brent  E09000005 1995-01-01   71306.56698  1995
# ...                   ...        ...        ...           ...   ...
# 15100              Sutton  E09000029 2021-03-01  395397.08970  2021
# 15101       Tower Hamlets  E09000030 2021-03-01  496246.71500  2021
# 15102      Waltham Forest  E09000031 2021-03-01  490895.15880  2021
# 15103          Wandsworth  E09000032 2021-03-01  598279.43470  2021
# 15104         Westminster  E09000033 2021-03-01  927993.33540  2021
#
# [10395 rows x 5 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# Yearly avg price
dfg = df.groupby(by = ['Borough_Name', 'Year']).mean()

# %%
dfg
# Out:
#                             Avg_price
# Borough_Name       Year
# Barking & Dagenham 1995  5.181797e+04
#                    1996  5.171819e+04
#                    1997  5.597426e+04
#                    1998  6.028582e+04
#                    1999  6.532093e+04
# ...                               ...
# Westminster        2017  1.064772e+06
#                    2018  1.020025e+06
#                    2019  9.559986e+05
#                    2020  9.601223e+05
#                    2021  9.401718e+05
#
# [891 rows x 1 columns]

# %%
dfg = dfg.reset_index()
dfg
# Out:
#            Borough_Name  Year     Avg_price
# 0    Barking & Dagenham  1995  5.181797e+04
# 1    Barking & Dagenham  1996  5.171819e+04
# 2    Barking & Dagenham  1997  5.597426e+04
# 3    Barking & Dagenham  1998  6.028582e+04
# 4    Barking & Dagenham  1999  6.532093e+04
# ..                  ...   ...           ...
# 886         Westminster  2017  1.064772e+06
# 887         Westminster  2018  1.020025e+06
# 888         Westminster  2019  9.559986e+05
# 889         Westminster  2020  9.601223e+05
# 890         Westminster  2021  9.401718e+05
#
# [891 rows x 3 columns]

# %%
'''
1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. 
For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].

2. Get the Average Price for that Borough, for the years 1998 and 2018.

3.Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.

4. Return that ratio.
'''

# Function from Tier 2 script to return the price ratio
def create_price_ratio(d):
    y1998 = float(d['Avg_price'][d['Year']==1998])
    y2018 = float(d['Avg_price'][d['Year']==2018])
    ratio = [y1998/y2018]
    return ratio

# %%
dfg.dtypes
# Out:
# Borough_Name     object
# Year              int64
# Avg_price       float64
# dtype: object

# %%
create_price_ratio(dfg[dfg['Borough_Name']=='Camden'])
# Out:
# [0.20261973503252542]

# %%
# Initialize a dict. key:value = Borough_Name:[Price ratio]
results = {}

# %%
# Iterate through all London boroughs to get the price ratios over the years from 1998 to 2018
for b in dfg['Borough_Name'].unique():
    borough = dfg[dfg['Borough_Name'] == b]
    results[b] = create_price_ratio(borough)
print(results)
# Out:
# {'Barking & Dagenham': [0.20422256235393685], 'Barnet': [0.22945274120785797], 'Bexley': [0.2353507654063011], 'Brent': [0.2043086864360114], 'Bromley': [0.24421308489837312], 'Camden': [0.20261973503252542], 'City of London': [0.18862157770244367], 'Croydon': [0.23803288028014047], 'Ealing': [0.23194048191708755], 'Enfield': [0.23455064269011863], 'Greenwich': [0.20995010893854218], 'Hackney': [0.16133493530705734], 'Hammersmith & Fulham': [0.24167443054605853], 'Haringey': [0.19475619095546956], 'Harrow': [0.24635417785626296], 'Havering': [0.23120155787014757], 'Hillingdon': [0.23807975835429931], 'Hounslow': [0.25148317824115635], 'Islington': [0.20643891170300285], 'Kensington & Chelsea': [0.19675491852791563], 'Kingston upon Thames': [0.23416190234282552], 'Lambeth': [0.20170435486140822], 'Lewisham': [0.1835124676472171], 'Merton': [0.21091380604361798], 'Newham': [0.18848754146121072], 'Redbridge': [0.2236545053715767], 'Richmond upon Thames': [0.24967779731157863], 'Southwar
# ...

# %%
price_ratios = pd.DataFrame(results)

# %%
price_ratios
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley   Camden  \
# 0            0.204223  0.229453  0.235351  0.204309  0.244213  0.20262
#
#    City of London   Croydon   Ealing   Enfield  ...    Merton    Newham  \
# 0        0.188622  0.238033  0.23194  0.234551  ...  0.210914  0.188488
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   0.223655              0.249678   0.181275  0.242806       0.216137
#
#    Waltham Forest  Wandsworth  Westminster
# 0        0.171387    0.210185     0.186791
#
# [1 rows x 33 columns]

# %%
price_ratios_T = price_ratios.T
price_ratios_T = price_ratios_T.reset_index()

# %%
price_ratios_T.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
pr = price_ratios_T.rename(columns={'index':'Borough', 0:'2018'})
pr.head()
# Out:
#               Borough      2018
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
pr = pr.sort_values(by='2018', ascending=False)

# %%
top15 = pr.head(15)

# %%
ax = top15[['Borough','2018']].plot(kind='bar')
ax.set_xticklabels(top15.Borough)
# Out:
# [Text(0, 0, 'Hounslow'),
#  Text(1, 0, 'Richmond upon Thames'),
#  Text(2, 0, 'Harrow'),
#  Text(3, 0, 'Bromley'),
#  Text(4, 0, 'Sutton'),
#  Text(5, 0, 'Hammersmith & Fulham'),
#  Text(6, 0, 'Hillingdon'),
#  Text(7, 0, 'Croydon'),
#  Text(8, 0, 'Bexley'),
#  Text(9, 0, 'Enfield'),
#  Text(10, 0, 'Kingston upon Thames'),
#  Text(11, 0, 'Ealing'),
#  Text(12, 0, 'Havering'),
#  Text(13, 0, 'Barnet'),
#  Text(14, 0, 'Redbridge')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %%
"""
In the past two decades, from 1998 to 2018, the London Borough of Hounslow has seen the greatest increate in house prices.
An astounding average increase of 25.1% annually!
Overall, even the lowest rate of increase over 20 years is impressive (Hackney at 16.1%). 
See summary of housing price changes below including just the top 15. 
Any wonder why London is one of the most expensive cities in the world? 
After the COVID-19 pandemic, it will be interesting to see how much more(?) housing prices have changed.
"""

top15
# Out:
#                  Borough      2018
# 17              Hounslow  0.251483
# 26  Richmond upon Thames  0.249678
# 14                Harrow  0.246354
# 4                Bromley  0.244213
# 28                Sutton  0.242806
# 12  Hammersmith & Fulham  0.241674
# 16            Hillingdon  0.238080
# 7                Croydon  0.238033
# 2                 Bexley  0.235351
# 9                Enfield  0.234551
# 20  Kingston upon Thames  0.234162
# 8                 Ealing  0.231940
# 15              Havering  0.231202
# 1                 Barnet  0.229453
# 25             Redbridge  0.223655

# %%
# Overall summary
pr
# Out:
#                  Borough      2018
# 17              Hounslow  0.251483
# 26  Richmond upon Thames  0.249678
# 14                Harrow  0.246354
# 4                Bromley  0.244213
# 28                Sutton  0.242806
# 12  Hammersmith & Fulham  0.241674
# 16            Hillingdon  0.238080
# 7                Croydon  0.238033
# 2                 Bexley  0.235351
# 9                Enfield  0.234551
# 20  Kingston upon Thames  0.234162
# 8                 Ealing  0.231940
# 15              Havering  0.231202
# 1                 Barnet  0.229453
# 25             Redbridge  0.223655
# 29         Tower Hamlets  0.216137
# 23                Merton  0.210914
# 31            Wandsworth  0.210185
# 10             Greenwich  0.209950
# 18             Islington  0.206439
# 3                  Brent  0.204309
# 0     Barking & Dagenham  0.204223
# 5                 Camden  0.202620
# 21               Lambeth  0.201704
# 19  Kensington & Chelsea  0.196755
# 13              Haringey  0.194756
# ...
